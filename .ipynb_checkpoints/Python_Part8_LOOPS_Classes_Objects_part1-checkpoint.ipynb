# %%
### Creating Class and Object
class Student:
    name= "Sangeet"

S1 = Student()
print (S1)

# %%
##
class Car:
    color = "Red"
    brand = "BMW"

car1 = Car()
print (car1.color)
print (car1.brand)
# Out:
# Red
# BMW

# %%
## init_Function or Constructor function

class Student:
    def __init__(self,name, marks):
        self.name = name
        self.marks = marks
        print ("Adding new Student in Database..")

s1 = Student("Ram", 65)
print (s1.name,s1.marks)

s2 = Student("Mondal",88)
print (s2.name, s2.marks)
# Out:
# Adding new Student in Database..
# Ram 65
# Adding new Student in Database..
# Mondal 88

# %%
## Class & Instance, Which thing is common we make it Arrtibutes. like College name, class name(Student)
class Student:
    college_name = "University of Hull"
    def __init__(self,name, marks):
        self.name = name
        self.marks = marks
        print ("Adding new Student in Database..")

s1 = Student("Ram", 65)
print (s1.name,s1.marks)

s2 = Student("Mondal",88)
print (s2.name, s2.marks)

print (Student.college_name)
# Out:
# Adding new Student in Database..
# Ram 65
# Adding new Student in Database..
# Mondal 88
# University of Hull

# %%
## Method, which function is written in class we called that method
class student:
    college_name = "University of Hull"

    def __init__(self, name, marks):
        self.name= name
        self.marks= marks

    def welcome(self):
        print("Welcome Student", self.name)

    def get_marks(self):
        return self.marks

s1 = student("Mondal",77)
s1.welcome()
print(s1.get_marks())
# Out:
# Welcome Student Mondal
# 77

# %%
## Practice: Create student class that takes name and marks of a 3 subjects as arguments in constructor. Then create a method to print the average

class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
        
    def get_avg(self):
        sum = 0 
        for val in self.marks:
            sum += val
        print("Hi", self.name, "Your Average score is: ", sum/3)

s1 = Student ("Nirmal", [55,66,77])
s1.get_avg()
# Out:
# Hi Nirmal Your Average score is:  66.0

# %%
## Static Methods

class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    @staticmethod
    def hello():
        print("hello")
        
    def get_avg(self):
        sum = 0 
        for val in self.marks:
            sum += val
        print("Hi", self.name, "Your Average score is: ", sum/3)

s1 = Student ("Nirmal", [55,66,77])
s1.get_avg()
# Out:
# Hi Nirmal Your Average score is:  66.0

# %%
## Abstraction

class Car:
    def __init__ (self,):
        self.acc = False
        self.brk = False
        self.clutch= False
        
    def start(self):
        self.acc= True
        self.clutch= True
        print ("Car Started..")

car1 = Car()
car1.start()
# Out:
# Car Started..

# %%
## Encapsulation =Warping data & functions into a single unit(Object) called Encapsulation. 
##Create account class with 2 attributes- balance and account number. Create a methods for debit, credit & printing the balance.
class Account:
    def __init__ (self, bal, acc):
        self.balance = bal
        self.account_no = acc

#Debit Method
    def debit(self, amount):
        self.balance -= amount
        print("USD", amount, "was Debited")
        print("Total Balanced =", self.get_balance())

#Credit Method
    def credit(self, amount):
        self.balance += amount
        print("USD", amount, "was Credited")
        print("Total Balance = ", self.get_balance())

    def get_balance (self):
        return self.balance

acc1 = Account(1000, 12345)
acc1.debit(1000)
acc1.credit(500)
acc1.credit(903)
acc1.credit(10)
# Out:
# USD 1000 was Debited
# Total Balanced = 0
# USD 500 was Credited
# Total Balance =  500
# USD 903 was Credited
# Total Balance =  1403
# USD 10 was Credited
# Total Balance =  1413
